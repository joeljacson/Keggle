# %% [markdown]
# <a href="https://colab.research.google.com/github/joeljacson/Keggle/blob/main/Predictive_Maintenance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9978107f-a9b7-47ec-a14b-930897a3be38" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9978107f-a9b7-47ec-a14b-930897a3be38">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# Check if the kaggle.json file is in the current directory
if 'kaggle.json' not in os.listdir():
    print("Please make sure you have uploaded the kaggle.json file.")
else:
    # Set up Kaggle API token
    # !mkdir -p ~/.kaggle
    # !cp kaggle.json ~/.kaggle/
    # !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d shivamb/machine-predictive-maintenance-classification
# Out:
# ...
#   0% 0.00/137k [00:00<?, ?B/s]
# 100% 137k/137k [00:00<00:00, 29.3MB/s]

# %%
import zipfile

with zipfile.ZipFile('/content/machine-predictive-maintenance-classification.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')
    zip_ref.close()

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/predictive_maintenance.csv')
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...
