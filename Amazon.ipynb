# %% [markdown]
# <a href="https://colab.research.google.com/github/joeljacson/Keggle/blob/main/Amazon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-dd80576b-543a-4dc8-bbd0-669a488e4685" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd80576b-543a-4dc8-bbd0-669a488e4685">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
import os

# Check if the kaggle.json file is in the current directory
if 'kaggle.json' not in os.listdir():
    print("Please make sure you have uploaded the kaggle.json file.")
else:
    # Set up Kaggle API token
    # !mkdir -p ~/.kaggle
    # !cp kaggle.json ~/.kaggle/
    # !chmod 600 ~/.kaggle/kaggle.json
# Out:
# Please make sure you have uploaded the kaggle.json file.

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8fe6ed79-5a54-46ca-a5e2-db7a7327ccff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fe6ed79-5a54-46ca-a5e2-db7a7327ccff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# Check if the kaggle.json file is in the current directory
if 'kaggle.json' not in os.listdir():
    print("Please make sure you have uploaded the kaggle.json file.")
else:
    # Set up Kaggle API token
    # !mkdir -p ~/.kaggle
    # !cp kaggle.json ~/.kaggle/
    # !chmod 600 ~/.kaggle/kaggle.json

# %%
import os

# Check if the kaggle.json file is in the current directory
if 'kaggle.json' not in os.listdir():
    print("Please make sure you have uploaded the kaggle.json file.")
else:
    # Set up Kaggle API token
    # !mkdir -p ~/.kaggle
    # !cp kaggle.json ~/.kaggle/
    # !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d arnavsmayan/amazon-prime-userbase-dataset
# Out:
# ...
# 100% 104k/104k [00:00<00:00, 381kB/s]
# 100% 104k/104k [00:00<00:00, 381kB/s]

# %%
import zipfile

with zipfile.ZipFile('/content/amazon-prime-userbase-dataset.zip') as zip_ref:
    zip_ref.extractall('/content/')
    zip_ref.close()

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('/content/amazon_prime_users.csv')
df.head()
# Out:
#    User ID              Name                   Email Address  \
# 0        1     Ronald Murphy      williamholland@example.com
# 1        2       Scott Allen             scott22@example.org
# 2        3  Jonathan Parrish            brooke16@example.org
# 3        4    Megan Williams         elizabeth31@example.net
# 4        5     Kathryn Brown  pattersonalexandra@example.org
#
#              Username Date of Birth  Gender        Location  \
# 0      williamholland    1953-06-03    Male  Rebeccachester
# 1             scott22    1978-07-08    Male   Mcphersonview
# 2            brooke16    1994-12-06  Female       Youngfort
# 3         elizabeth31    1964-12-22  Female    Feliciashire
# 4  pattersonalexandra    1961-06-04    Male    Port Deborah
#
#   Membership Start Date Membership End Date Subscription Plan  \
# 0            2024-01-15          2025-01-14            Annual
# 1            2024-01-07          2025-01-06           Monthly
# ...
