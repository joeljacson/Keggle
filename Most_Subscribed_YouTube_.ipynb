# %% [markdown]
# <a href="https://colab.research.google.com/github/joeljacson/Keggle/blob/main/Most_Subscribed_YouTube_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-94d05d40-2a37-4123-92b8-82d1b113b283" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94d05d40-2a37-4123-92b8-82d1b113b283">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-52604bbc-75b5-4959-a808-575e4e018cc2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52604bbc-75b5-4959-a808-575e4e018cc2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# Check if the kaggle.json file is in the current directory
if 'kaggle.json' not in os.listdir():
    print("Please make sure you have uploaded the kaggle.json file.")
else:
    # Set up Kaggle API token
    # !mkdir -p ~/.kaggle
    # !cp kaggle.json ~/.kaggle/
    # !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d sukhmandeepsinghbrar/most-subscribed-youtube-channel
# Out:
# ...
#   0% 0.00/1.30k [00:00<?, ?B/s]
# 100% 1.30k/1.30k [00:00<00:00, 2.24MB/s]

# %%
import zipfile

with zipfile.ZipFile('/content/most-subscribed-youtube-channel.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')
    zip_ref.close()

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('/content/most-subscribed-youtube-channel.zip')
df.head()
# Out:
#                                   Name Brand channel  Subscribers (millions)  \
# 0                             T-Series           Yes                   249.0
# 1                              MrBeast            No                   184.0
# 2                            Cocomelon           Yes                   165.0
# 3  Sony Entertainment Television India           Yes                   162.0
# 4                      Kids Diana Show           Yes                   113.0
#
#       Primary language       Category                 Country
# 0          Hindi[7][8]          Music                   India
# 1              English  Entertainment           United States
# 2              English      Education           United States
# 3             Hindi[9]  Entertainment                   India
# 4  English[10][11][12]  Entertainment  Ukraine- United States
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
# ...
